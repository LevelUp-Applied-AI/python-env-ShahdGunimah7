# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#     name  score  passed
# 0   Sara     88    True
# 1   Lina     74    True
# 2   Maha     59   False
# 3   Noor     92    True
# 4  Ahmad     63   False
#            score
# count   5.000000
# mean   75.200000
# std    14.652645
# min    59.000000
# 25%    63.000000
# 50%    74.000000
# 75%    88.000000
# max    92.000000
